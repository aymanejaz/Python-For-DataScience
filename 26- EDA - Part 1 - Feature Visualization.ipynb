# %% [markdown]
# ## Analyzing Individual Feature Patterns Using Visualization
#
# Analyzing Individual Feature Patterns Using Visualization refers to the process of examining and understanding specific attributes or features in a dataset by utilizing visual representations. Visualization techniques, such as histograms, scatter plots, box plots, and bar charts, allow us to gain insights into the distribution, relationships, trends, and patterns within individual features. By visualizing the data, we can better comprehend the characteristics and behavior of each feature, aiding in making informed data-driven decisions and drawing meaningful conclusions.

# %% [markdown]
# ####  Exploratory Data Analysis (EDA)
# EDA is the process of analyzing and summarizing data sets to gain insights and understand the underlying patterns and relationships. It involves visualizing data, identifying missing values, outliers, and distributions, as well as performing statistical tests and creating preliminary models. EDA helps in understanding the data before applying any formal statistical techniques or building predictive models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Create a dictionary with the data
data = {
    'Name': ['John', 'Emma', 'Michael', 'Sophia', 'David', 'Doe', 'Emo' ],
    'Age': [25, 30, 35, 28, 34, 34, 60],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female',],
    'Income': [50000, 60000, 70000, 55000, 40000, 73000, 47000 ]
}

# Create a DataFrame from the dictionary
data = pd.DataFrame(data)

# Display the DataFrame
data
# Out:
#       Name  Age  Gender  Income
# 0     John   25    Male   50000
# 1     Emma   30  Female   60000
# 2  Michael   35    Male   70000
# 3   Sophia   28  Female   55000
# 4    David   34  Female   40000
# 5      Doe   34    Male   73000
# 6      Emo   60  Female   47000

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Name      0
# Age       0
# Gender    0
# Income    0
# dtype: int64

# %%
# Visualize the distribution of a numerical variable
plt.hist(data['Age'], bins=5)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# This code snippet is a Python code using the matplotlib library to create a histogram that visualizes the distribution of a numerical variable called 'Age'. The dataset is represented by the variable 'data'.
#
# Explanation:
# 1. `plt.hist(data['Age'], bins=5)`: This line generates a histogram plot for the 'Age' variable using the `hist` function from the matplotlib library. The data used for the histogram is taken from the 'Age' column in the 'data' DataFrame. The `bins=5` parameter specifies that the histogram should be divided into five bins, each representing a range of 'Age' values.
#
# 2. `plt.xlabel('Age')`: This line sets the label for the x-axis of the plot as 'Age'.
#
# 3. `plt.ylabel('Count')`: This line sets the label for the y-axis of the plot as 'Count', representing the number of occurrences of each age range in the dataset.
#
# 4. `plt.title('Distribution of Age')`: This line sets the title of the plot as 'Distribution of Age', describing the purpose of the visualization.
#
# 5. `plt.show()`: This line displays the histogram plot on the screen.
#
# Overall, this code helps us to understand the distribution of ages in the 'data' DataFrame by presenting the data in the form of a histogram, which shows the frequency of different age ranges in the dataset. The histogram allows us to quickly grasp the pattern and central tendency of the 'Age' variable.

# %%
# Visualize the distribution of a numerical variable
plt.hist(data['Age'], bins=9)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
# Visualize the distribution of a numerical variable
plt.hist(data['Age'], bins=15)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
# Visualize the distribution of a numerical variable
plt.hist(data['Age'], bins=2)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
# Create a dictionary with the data
data = {
    'Income': [50000, 60000, 70000, 55000],
    'Spending': [25000, 30000, 35000, 20000]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#    Income  Spending
# 0   50000     25000
# 1   60000     30000
# 2   70000     35000
# 3   55000     20000

# %%
# Explore the relationship between two variables
plt.scatter(data['Income'], data['Spending'])
plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('Income vs. Spending')
plt.show()

# %%
# Visualize the distribution of a numerical variable
plt.hist(data['Income'], bins=10)
plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('Income vs. Spending')
plt.show()

# %%
# list the data types for each column
print(df.dtypes)
# Out:
# Income      int64
# Spending    int64
# dtype: object

# %% [markdown]
# ### Working with clean data - cleaned in last Data wrangling part
#
# In this example, we load a dataset using pandas, display the first few rows, check for missing values, and visualize the distribution of the 'age' variable using a histogram. We also explore the relationship between the 'income' and 'spending' variables using a scatter plot. These steps help us understand the data and identify any patterns or outliers.

# %%
# working with clean data - cleaned in last Data wrangling part

df = pd.read_csv('clean_df')
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make num-of-doors
# 0           0          3                122  alfa-romero          two  \
# 1           1          3                122  alfa-romero          two
# 2           2          1                122  alfa-romero          two
# 3           3          2                164         audi         four
# 4           4          2                164         audi         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...
# 0  convertible          rwd           front        88.6  0.811148  ...  \
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    city-L/100km  length_new  length_zscore horsepower-binned fuel-type-diesel
# ...

# %%
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566903
# stroke            -0.055390  1.000000           0.187871    0.098128
# compression-ratio  0.001263  0.187871           1.000000   -0.214489
# horsepower         0.566903  0.098128          -0.214489    1.000000

# %% [markdown]
# ### Continuous Numerical Variables:
# Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.
#
# In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data.
#
# Let's see several examples of different linear relationships:
#
# ### Positive Linear Relationship
# Let's find the scatterplot of "engine-size" and "price".

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53589.17696291171)

# %% [markdown]
# As the engine-size goes up, the price goes up: this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line.
#
# We can examine the correlation between 'engine-size' and 'price' and see that it's approximately 0.87.

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Highway mpg is a potential predictor variable of price. Let's find the scatterplot of "highway-L/100km" and "price".

# %%
sns.regplot(x="highway-L/100km", y="price", data=df)
# Out:
# <Axes: xlabel='highway-L/100km', ylabel='price'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-L/100km', 'price',
#        'city-L/100km', 'length_new', 'length_zscore', 'horsepower-binned',
#        'fuel-type-diesel', 'fuel-type-gas', 'aspiration-std',
#        'aspiration-turbo', 'aspiration-std.1', 'aspiration-turbo.1'],
#       dtype='object')

# %%
df[['highway-L/100km', 'price']].corr()
# Out:
#                  highway-L/100km     price
# highway-L/100km         1.000000  0.801118
# price                   0.801118  1.000000

# %% [markdown]
# ### Weak Linear Relationship
# Let's see if "peak-rpm" is a predictor variable of "price".

# %%
sns.regplot(x="peak-rpm", y="price", data=df)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %% [markdown]
# Peak rpm does not seem like a good predictor of the price at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.
#
# We can examine the correlation between 'peak-rpm' and 'price' and see it's approximately -0.101616.

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# correlation  between x="stroke" and y="price".

# %%
df[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %%
sns.regplot(x='stroke', y='price', data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# ### Categorical Variables
# These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.
#
# Let's look at the relationship between "body-style" and "price".

# %%
sns.boxplot(x="body-style", y="price", data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# We see that the distributions of price between the different body-style categories have a significant overlap, so body-style would not be a good predictor of price. Let's examine engine "engine-location" and "price":

# %%
sns.boxplot(x="engine-location", y="price", data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %% [markdown]
# Here we see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.
#
# Let's examine "drive-wheels" and "price".

# %%
# drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
sns.boxplot(x='length', y='width', data=df)
# Out:
# <Axes: xlabel='length', ylabel='width'>
